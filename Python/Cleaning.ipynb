# %% [markdown]
# # Cleaning

# %%
import pandas as pd
import re

# %% [markdown]
# ## Koro

# %%
koro = pd.read_csv('df_koro.csv')

# %%
koro.shape
# Out:
# (221, 15)

# %%
koro.head()
# Out:
#    Unnamed: 0                                          product  \
# 0           0        Soja Protein Crispies 58 % mit Kakao 1 kg
# 1           1                       Schokodrops mit Xylit 1 kg
# 2           2  Schoko Protein Crunchies ohne Zuckerzusatz 1 kg
# 3           3                  Soja Protein Crispies 60 % 1 kg
# 4           4       Bohnen-Erbsen-Mix geröstet & gesalzen 1 kg
#
#                                                links          price weight  \
# 0  https://www.korodrogerie.de/soja-protein-crisp...  \n\n14,00 €\n   1 kg
# 1  https://www.korodrogerie.de/schokodrops-mit-xy...  \n\n21,00 €\n   1 kg
# 2  https://www.korodrogerie.de/schoko-protein-cru...  \n\n20,00 €\n   1 kg
# 3  https://www.korodrogerie.de/soja-protein-crisp...  \n\n13,00 €\n   1 kg
# 4  https://www.korodrogerie.de/bohnen-erbsen-mix-...  \n\n11,50 €\n   1 kg
#
#                                            kcal    fat sat_fat   carbs  sugar  \
# 0  1535                                   / 362  1,9 g   0,4 g  28,2 g  9,1 g
# 1  2290                                   / 555   46 g    28 g    31 g  1,0 g
# 2  1875                                   / 448   28 g    12 g    37 g  1,4 g
# 3  1541                                   / 363  1,8 g   0,2 g    26 g  0,8 g
# 4  1766                                   / 421   14 g   2,3 g    35 g  6,7 g
#
#    fibre protein    salt                                        ingredients  \
# 0  1,8 g    58 g   2,7 g  74 % SOJAPROTEIN, Reisgrieß, Zucker, 4 % Kakao...
# 1   10 g   9,2 g  0,07 g  Kakaomasse, 25 % Süßungsmittel: Xylit; Kakaobu...
# 2  8,3 g    21 g  0,36 g  Süßungsmittel: Maltit, ERDNUSSKERNE, 20 % Prot...
# 3  0,8 g    60 g   3,2 g  68 % SOJAPROTEIN, Reisgriess, SOJAMEHL, Salz\t...
# 4   10 g    33 g   1,0 g  19 % SCHWARZE SOJABOHNEN, 19 % EDAMAME-BOHNEN,...
#
#                                           photo_link
# 0  https://koro2.imgix.net/media/image/f1/50/81/C...
# 1  https://koro2.imgix.net/media/image/2c/01/f8/S...
# 2  https://koro2.imgix.net/media/image/30/78/62/P...
# 3  https://koro2.imgix.net/media/image/84/55/ca/C...
# 4  https://koro2.imgix.net/media/image/a9/37/79/B...

# %% [markdown]
# ### Cleaning overview
#
# - [x] removing duplicate index column
# - [x] removing weight from product name
# - [x] new column with brand: "value == Koro" for all rows
# - [x] removing extra characters from price
# - [ ] cleaning weight column / getting info about weight from product name
# - [x] removing 'g' from fat, sat_fat, carbs, sugar, fibre, protein, salt
# - [x] split kcal-column in kJ and kcal
#
# Maybe:
#
# - [ ] new column price/gr?
# - [ ] ingredients: use first ingredient?

# %% [markdown]
# **Dropping duplicate index column**

# %%
koro = koro.drop('Unnamed: 0', axis=1)
koro.columns
# Out:
# Index(['product', 'links', 'price', 'weight', 'kcal', 'fat', 'sat_fat',
#        'carbs', 'sugar', 'fibre', 'protein', 'salt', 'ingredients',
#        'photo_link'],
#       dtype='object')

# %% [markdown]
# **Clean product name**

# %%
def clean_name(x):
    return re.sub(r'\d{2,3}\s\w+|\d{1}\s\w{2}|\d{1}\sx', '', x)

# %%
koro["product_clean"] = koro["product"].apply(clean_name)
koro["product_clean"]
# Out:
# 0            Soja Protein Crispies 58 % mit Kakao
# 1                           Schokodrops mit Xylit
# 2      Schoko Protein Crunchies ohne Zuckerzusatz
# 3                      Soja Protein Crispies 60 %
# 4           Bohnen-Erbsen-Mix geröstet & gesalzen
#                           ...
# 216                     Bio gepuffte Ananasstücke
# 217          Bio gepuffte schwarze Johannisbeeren
# 218                          Bio gepuffte Kirsche
# 219                             Bio Cracker Pizza
# 220                            Bio Cracker Pizza
# Name: product_clean, Length: 221, dtype: object

# %% [markdown]
# **Adding brand column**

# %%
koro['brand'] = 'Koro'
koro.head()
# Out:
#                                            product  \
# 0        Soja Protein Crispies 58 % mit Kakao 1 kg
# 1                       Schokodrops mit Xylit 1 kg
# 2  Schoko Protein Crunchies ohne Zuckerzusatz 1 kg
# 3                  Soja Protein Crispies 60 % 1 kg
# 4       Bohnen-Erbsen-Mix geröstet & gesalzen 1 kg
#
#                                                links          price weight  \
# 0  https://www.korodrogerie.de/soja-protein-crisp...  \n\n14,00 €\n   1 kg
# 1  https://www.korodrogerie.de/schokodrops-mit-xy...  \n\n21,00 €\n   1 kg
# 2  https://www.korodrogerie.de/schoko-protein-cru...  \n\n20,00 €\n   1 kg
# 3  https://www.korodrogerie.de/soja-protein-crisp...  \n\n13,00 €\n   1 kg
# 4  https://www.korodrogerie.de/bohnen-erbsen-mix-...  \n\n11,50 €\n   1 kg
#
#                                            kcal    fat sat_fat   carbs  sugar  \
# 0  1535                                   / 362  1,9 g   0,4 g  28,2 g  9,1 g
# 1  2290                                   / 555   46 g    28 g    31 g  1,0 g
# 2  1875                                   / 448   28 g    12 g    37 g  1,4 g
# 3  1541                                   / 363  1,8 g   0,2 g    26 g  0,8 g
# 4  1766                                   / 421   14 g   2,3 g    35 g  6,7 g
#
#    fibre protein    salt                                        ingredients  \
# 0  1,8 g    58 g   2,7 g  74 % SOJAPROTEIN, Reisgrieß, Zucker, 4 % Kakao...
# 1   10 g   9,2 g  0,07 g  Kakaomasse, 25 % Süßungsmittel: Xylit; Kakaobu...
# 2  8,3 g    21 g  0,36 g  Süßungsmittel: Maltit, ERDNUSSKERNE, 20 % Prot...
# 3  0,8 g    60 g   3,2 g  68 % SOJAPROTEIN, Reisgriess, SOJAMEHL, Salz\t...
# 4   10 g    33 g   1,0 g  19 % SCHWARZE SOJABOHNEN, 19 % EDAMAME-BOHNEN,...
#
#                                           photo_link  \
# 0  https://koro2.imgix.net/media/image/f1/50/81/C...
# 1  https://koro2.imgix.net/media/image/2c/01/f8/S...
# 2  https://koro2.imgix.net/media/image/30/78/62/P...
# 3  https://koro2.imgix.net/media/image/84/55/ca/C...
# 4  https://koro2.imgix.net/media/image/a9/37/79/B...
#
#                                  product_clean brand
# 0        Soja Protein Crispies 58 % mit Kakao   Koro
# 1                       Schokodrops mit Xylit   Koro
# 2  Schoko Protein Crunchies ohne Zuckerzusatz   Koro
# 3                  Soja Protein Crispies 60 %   Koro
# 4       Bohnen-Erbsen-Mix geröstet & gesalzen   Koro

# %% [markdown]
# **Cleaning price column**

# %%
def clean_price(col):
    
    cleaned = []
    
    for p in col:
        price = str(p).replace('\n', '').replace('€', '').replace(',', '.')
        cleaned.append(float(price))   
        
    return cleaned

# %%
koro['price_clean'] = clean_price(koro['price'])

# %%
koro['price_clean']
# Out:
# 0      14.0
# 1      21.0
# 2      20.0
# 3      13.0
# 4      11.5
#        ...
# 216    18.5
# 217    24.0
# 218    20.0
# 219     5.0
# 220    27.5
# Name: price_clean, Length: 221, dtype: float64

# %% [markdown]
# **Cleaning weight column**

# %%
koro['weight'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         1 kg
# 1         1 kg
# 2         1 kg
# 3         1 kg
# 4         1 kg
#         ...
# 216      Polen
# 217      Polen
# 218      Polen
# 219    Italien
# 220    Italien
# Name: weight, Length: 221, dtype: object>

# %%
def clean_weight(x):
    return re.findall(r'\d{2,3}\s\w+|\d{1}\s\w{2}|\d{1}\sx', '', x)

# %%
weights = []
for p in koro['product']:
    weight = clean_weight(p)
    weights.append(weight)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9d6a8fa6c55f> in <module>
#       1 weights = []
#       2 for p in koro['product']:
# ----> 3     weight = clean_weight(p)
#       4     weights.append(weight)
#
# <ipython-input-13-834078b4dfa7> in clean_weight(x)
#       1 def clean_weight(x):
# ----> 2     return re.findall(r'\d{2,3}\s\w+|\d{1}\s\w{2}|\d{1}\sx', '', x)
#
# c:\users\katha\appdata\local\programs\python\python39\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# c:\users\katha\appdata\local\programs\python\python39\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# c:\users\katha\appdata\local\programs\python\python39\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# c:\users\katha\appdata\local\programs\python\python39\lib\sre_parse.py in parse(str, flags, state)
#     946
#     947     try:
# --> 948         p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949     except Verbose:
#     950         # the VERBOSE flag was switched on inside the pattern.  to be
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %% [markdown]
# **Cleaning nutrient columns**

# %%
def nutrient_cleaner(col):
    
    cleaned = []
    
    for n in col:
        n = str(n).replace('g', '').replace(',', '')
        cleaned.append(float(n))
    
    return cleaned

# %%
koro['fat_clean'] = nutrient_cleaner(koro['fat'])
koro['fat_clean']
# Out:
# 0      19.0
# 1      46.0
# 2      28.0
# 3      18.0
# 4      14.0
#        ...
# 216     0.0
# 217    23.0
# 218     5.0
# 219    13.0
# 220    13.0
# Name: fat_clean, Length: 221, dtype: float64

# %%
def batch_cleaning_nutrients(df, in_columns=[]):
    
    for col in df.columns:
        if col in in_columns:
            
            df[col] = nutrient_cleaner(df[col])
            
    return df

# %%
batch_cleaning_nutrients(koro, in_columns=['fat','sat_fat', 'carbs', 'sugar', 'fibre', 'protein', 'salt'])
# Out:
#                                              product  \
# 0          Soja Protein Crispies 58 % mit Kakao 1 kg
# 1                         Schokodrops mit Xylit 1 kg
# 2    Schoko Protein Crunchies ohne Zuckerzusatz 1 kg
# 3                    Soja Protein Crispies 60 % 1 kg
# 4         Bohnen-Erbsen-Mix geröstet & gesalzen 1 kg
# ..                                               ...
# 216                  Bio gepuffte Ananasstücke 500 g
# 217       Bio gepuffte schwarze Johannisbeeren 500 g
# 218                       Bio gepuffte Kirsche 500 g
# 219                          Bio Cracker Pizza 500 g
# 220                      Bio Cracker Pizza 6 x 500 g
#
#                                                  links          price  \
# 0    https://www.korodrogerie.de/soja-protein-crisp...  \n\n14,00 €\n
# 1    https://www.korodrogerie.de/schokodrops-mit-xy...  \n\n21,00 €\n
# 2    https://www.korodrogerie.de/schoko-protein-cru...  \n\n20,00 €\n
# 3    https://www.korodrogerie.de/soja-protein-crisp...  \n\n13,00 €\n
# 4    https://www.korodrogerie.de/bohnen-erbsen-mix-...  \n\n11,50 €\n
# ..                                                 ...            ...
# 216  https://www.korodrogerie.de/bio-gepuffte-anana...  \n\n18,50 €\n
# 217  https://www.korodrogerie.de/bio-gepuffte-schwa...  \n\n24,00 €\n
# 218  https://www.korodrogerie.de/bio-gepuffte-kirsc...  \n\n20,00 €\n
# 219  https://www.korodrogerie.de/bio-cracker-pizza-...   \n\n5,00 €\n
# 220  https://www.korodrogerie.de/bio-cracker-pizza-...  \n\n27,50 €\n
#
#       weight                                           kcal   fat  sat_fat  \
# 0       1 kg   1535                                   / 362  19.0      4.0
# 1       1 kg   2290                                   / 555  46.0     28.0
# 2       1 kg   1875                                   / 448  28.0     12.0
# 3       1 kg   1541                                   / 363  18.0      2.0
# 4       1 kg   1766                                   / 421  14.0     23.0
# ..       ...                                            ...   ...      ...
# 216    Polen   1612                                   / 380   0.0      0.0
# 217    Polen   1336                                   / 319  23.0      4.0
# 218    Polen   1472                                   / 348   5.0      2.0
# 219  Italien  1830                                    / 435  13.0     11.0
# 220  Italien   1830                                   / 435  13.0     11.0
#
#      carbs  sugar  fibre  protein  salt  \
# 0    282.0   91.0   18.0     58.0  27.0
# 1     31.0   10.0   10.0     92.0   7.0
# 2     37.0   14.0   83.0     21.0  36.0
# 3     26.0    8.0    8.0     60.0  32.0
# 4     35.0   67.0   10.0     33.0  10.0
# ..     ...    ...    ...      ...   ...
# 216   87.0   85.0   79.0     30.0   0.0
# 217   54.0   44.0   31.0     50.0   2.0
# 218   75.0   41.0   95.0     60.0   2.0
# 219   67.0   23.0   29.0     10.0  29.0
# 220   67.0   23.0   29.0     10.0  29.0
#
#                                            ingredients  \
# 0    74 % SOJAPROTEIN, Reisgrieß, Zucker, 4 % Kakao...
# 1    Kakaomasse, 25 % Süßungsmittel: Xylit; Kakaobu...
# 2    Süßungsmittel: Maltit, ERDNUSSKERNE, 20 % Prot...
# 3    68 % SOJAPROTEIN, Reisgriess, SOJAMEHL, Salz\t...
# 4    19 % SCHWARZE SOJABOHNEN, 19 % EDAMAME-BOHNEN,...
# ..                                                 ...
# 216       KoRo Handels GmbHKoppenplatz 9, 10115 Berlin
# 217       KoRo Handels GmbHKoppenplatz 9, 10115 Berlin
# 218       KoRo Handels GmbHKoppenplatz 9, 10115 Berlin
# 219       KoRo Handels GmbHKoppenplatz 9, 10115 Berlin
# 220       KoRo Handels GmbHKoppenplatz 9, 10115 Berlin
#
#                                             photo_link  \
# 0    https://koro2.imgix.net/media/image/f1/50/81/C...
# 1    https://koro2.imgix.net/media/image/2c/01/f8/S...
# 2    https://koro2.imgix.net/media/image/30/78/62/P...
# 3    https://koro2.imgix.net/media/image/84/55/ca/C...
# 4    https://koro2.imgix.net/media/image/a9/37/79/B...
# ..                                                 ...
# 216  https://koro2.imgix.net/media/image/b8/cc/8c/B...
# 217  https://koro2.imgix.net/media/image/47/fa/41/B...
# 218  https://koro2.imgix.net/media/image/38/f1/16/P...
# 219  https://koro2.imgix.net/media/image/7e/83/e0/C...
# 220  https://koro2.imgix.net/media/image/7e/83/e0/C...
#
#                                    product_clean brand  price_clean  fat_clean
# 0          Soja Protein Crispies 58 % mit Kakao   Koro         14.0       19.0
# 1                         Schokodrops mit Xylit   Koro         21.0       46.0
# 2    Schoko Protein Crunchies ohne Zuckerzusatz   Koro         20.0       28.0
# 3                    Soja Protein Crispies 60 %   Koro         13.0       18.0
# 4         Bohnen-Erbsen-Mix geröstet & gesalzen   Koro         11.5       14.0
# ..                                           ...   ...          ...        ...
# 216                   Bio gepuffte Ananasstücke   Koro         18.5        0.0
# 217        Bio gepuffte schwarze Johannisbeeren   Koro         24.0       23.0
# 218                        Bio gepuffte Kirsche   Koro         20.0        5.0
# 219                           Bio Cracker Pizza   Koro          5.0       13.0
# 220                          Bio Cracker Pizza    Koro         27.5       13.0
#
# [221 rows x 18 columns]

# %% [markdown]
# **Splitting kcal column**

# %%
koro[['kj_clean','kcal_clean']] = koro['kcal'].str.split('/', expand=True)

# %%
koro['kj_clean'] = koro['kj_clean'].astype('float')
koro['kcal_clean'] = koro['kcal_clean'].astype('float')

# %%
koro.head(5)
# Out:
#                                            product  \
# 0        Soja Protein Crispies 58 % mit Kakao 1 kg
# 1                       Schokodrops mit Xylit 1 kg
# 2  Schoko Protein Crunchies ohne Zuckerzusatz 1 kg
# 3                  Soja Protein Crispies 60 % 1 kg
# 4       Bohnen-Erbsen-Mix geröstet & gesalzen 1 kg
#
#                                                links          price weight  \
# 0  https://www.korodrogerie.de/soja-protein-crisp...  \n\n14,00 €\n   1 kg
# 1  https://www.korodrogerie.de/schokodrops-mit-xy...  \n\n21,00 €\n   1 kg
# 2  https://www.korodrogerie.de/schoko-protein-cru...  \n\n20,00 €\n   1 kg
# 3  https://www.korodrogerie.de/soja-protein-crisp...  \n\n13,00 €\n   1 kg
# 4  https://www.korodrogerie.de/bohnen-erbsen-mix-...  \n\n11,50 €\n   1 kg
#
#                                            kcal   fat  sat_fat  carbs  sugar  \
# 0  1535                                   / 362  19.0      4.0  282.0   91.0
# 1  2290                                   / 555  46.0     28.0   31.0   10.0
# 2  1875                                   / 448  28.0     12.0   37.0   14.0
# 3  1541                                   / 363  18.0      2.0   26.0    8.0
# 4  1766                                   / 421  14.0     23.0   35.0   67.0
#
#    fibre  protein  salt                                        ingredients  \
# 0   18.0     58.0  27.0  74 % SOJAPROTEIN, Reisgrieß, Zucker, 4 % Kakao...
# 1   10.0     92.0   7.0  Kakaomasse, 25 % Süßungsmittel: Xylit; Kakaobu...
# 2   83.0     21.0  36.0  Süßungsmittel: Maltit, ERDNUSSKERNE, 20 % Prot...
# 3    8.0     60.0  32.0  68 % SOJAPROTEIN, Reisgriess, SOJAMEHL, Salz\t...
# 4   10.0     33.0  10.0  19 % SCHWARZE SOJABOHNEN, 19 % EDAMAME-BOHNEN,...
#
#                                           photo_link  \
# 0  https://koro2.imgix.net/media/image/f1/50/81/C...
# 1  https://koro2.imgix.net/media/image/2c/01/f8/S...
# 2  https://koro2.imgix.net/media/image/30/78/62/P...
# 3  https://koro2.imgix.net/media/image/84/55/ca/C...
# 4  https://koro2.imgix.net/media/image/a9/37/79/B...
#
#                                  product_clean brand  price_clean  fat_clean  \
# 0        Soja Protein Crispies 58 % mit Kakao   Koro         14.0       19.0
# 1                       Schokodrops mit Xylit   Koro         21.0       46.0
# 2  Schoko Protein Crunchies ohne Zuckerzusatz   Koro         20.0       28.0
# 3                  Soja Protein Crispies 60 %   Koro         13.0       18.0
# 4       Bohnen-Erbsen-Mix geröstet & gesalzen   Koro         11.5       14.0
#
#    kj_clean  kcal_clean
# 0    1535.0       362.0
# 1    2290.0       555.0
# 2    1875.0       448.0
# 3    1541.0       363.0
# 4    1766.0       421.0

# %% [markdown]
# **Cleaning final dataframe**

# %%
koro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        221 non-null    object
#  1   links          221 non-null    object
#  2   price          221 non-null    object
#  3   weight         221 non-null    object
#  4   kcal           221 non-null    object
#  5   fat            221 non-null    float64
#  6   sat_fat        220 non-null    float64
#  7   carbs          220 non-null    float64
#  8   sugar          220 non-null    float64
#  9   fibre          219 non-null    float64
#  10  protein        221 non-null    float64
#  11  salt           221 non-null    float64
#  12  ingredients    221 non-null    object
#  13  photo_link     221 non-null    object
#  14  product_clean  221 non-null    object
#  15  brand          221 non-null    object
#  16  price_clean    221 non-null    float64
#  17  fat_clean      221 non-null    float64
#  18  kj_clean       221 non-null    float64
#  19  kcal_clean     221 non-null    float64
# dtypes: float64(11), object(9)
# memory usage: 34.7+ KB

# %%
drop_list = ['price', 'weight', 'kcal', 'fat_clean','ingredients']
koro = koro.drop(drop_list, axis=1)

# %%
koro = koro.reindex(columns=['product_clean','brand','price_clean', 'kj_clean', 'kcal_clean', 'fat', 'sat_fat', 'carbs', 'sugar', 'fibre', 'protein', 'salt',
                            'links', 'photo_link'])

# %%
koro
# Out:
#                                    product_clean brand  price_clean  kj_clean  \
# 0          Soja Protein Crispies 58 % mit Kakao   Koro         14.0    1535.0
# 1                         Schokodrops mit Xylit   Koro         21.0    2290.0
# 2    Schoko Protein Crunchies ohne Zuckerzusatz   Koro         20.0    1875.0
# 3                    Soja Protein Crispies 60 %   Koro         13.0    1541.0
# 4         Bohnen-Erbsen-Mix geröstet & gesalzen   Koro         11.5    1766.0
# ..                                           ...   ...          ...       ...
# 216                   Bio gepuffte Ananasstücke   Koro         18.5    1612.0
# 217        Bio gepuffte schwarze Johannisbeeren   Koro         24.0    1336.0
# 218                        Bio gepuffte Kirsche   Koro         20.0    1472.0
# 219                           Bio Cracker Pizza   Koro          5.0    1830.0
# 220                          Bio Cracker Pizza    Koro         27.5    1830.0
#
#      kcal_clean   fat  sat_fat  carbs  sugar  fibre  protein  salt  \
# 0         362.0  19.0      4.0  282.0   91.0   18.0     58.0  27.0
# 1         555.0  46.0     28.0   31.0   10.0   10.0     92.0   7.0
# 2         448.0  28.0     12.0   37.0   14.0   83.0     21.0  36.0
# 3         363.0  18.0      2.0   26.0    8.0    8.0     60.0  32.0
# 4         421.0  14.0     23.0   35.0   67.0   10.0     33.0  10.0
# ..          ...   ...      ...    ...    ...    ...      ...   ...
# 216       380.0   0.0      0.0   87.0   85.0   79.0     30.0   0.0
# 217       319.0  23.0      4.0   54.0   44.0   31.0     50.0   2.0
# 218       348.0   5.0      2.0   75.0   41.0   95.0     60.0   2.0
# 219       435.0  13.0     11.0   67.0   23.0   29.0     10.0  29.0
# 220       435.0  13.0     11.0   67.0   23.0   29.0     10.0  29.0
#
#                                                  links  \
# 0    https://www.korodrogerie.de/soja-protein-crisp...
# 1    https://www.korodrogerie.de/schokodrops-mit-xy...
# 2    https://www.korodrogerie.de/schoko-protein-cru...
# 3    https://www.korodrogerie.de/soja-protein-crisp...
# 4    https://www.korodrogerie.de/bohnen-erbsen-mix-...
# ..                                                 ...
# 216  https://www.korodrogerie.de/bio-gepuffte-anana...
# 217  https://www.korodrogerie.de/bio-gepuffte-schwa...
# 218  https://www.korodrogerie.de/bio-gepuffte-kirsc...
# 219  https://www.korodrogerie.de/bio-cracker-pizza-...
# 220  https://www.korodrogerie.de/bio-cracker-pizza-...
#
#                                             photo_link
# 0    https://koro2.imgix.net/media/image/f1/50/81/C...
# 1    https://koro2.imgix.net/media/image/2c/01/f8/S...
# 2    https://koro2.imgix.net/media/image/30/78/62/P...
# 3    https://koro2.imgix.net/media/image/84/55/ca/C...
# 4    https://koro2.imgix.net/media/image/a9/37/79/B...
# ..                                                 ...
# 216  https://koro2.imgix.net/media/image/b8/cc/8c/B...
# 217  https://koro2.imgix.net/media/image/47/fa/41/B...
# 218  https://koro2.imgix.net/media/image/38/f1/16/P...
# 219  https://koro2.imgix.net/media/image/7e/83/e0/C...
# 220  https://koro2.imgix.net/media/image/7e/83/e0/C...
#
# [221 rows x 14 columns]

# %% [markdown]
# ## Kokku

# %%
kokku = pd.read_csv('df_kokku.csv')

# %%
kokku.shape
# Out:
# (549, 9)

# %%
kokku.head()
# Out:
#    Unnamed: 0                                            product  \
# 0           0                                    Eisbonbon - 75g
# 1           1                              Stollenkonfekt - 100g
# 2           2  Veganer °Schokodrops° Dinkelstollen mit Puderz...
# 3           3  3 Stollenscheiben °Schokodrops° (ohne Rosinen)...
# 4           4              Veganer °Rosinen° Dinkelstollen - 1kg
#
#              brand  weight                                              links  \
# 0          Bio4You   - 75g         https://kokku-online.de/bio4you-eisbonbon/
# 1  Bäckerei Sachse  - 100g  https://kokku-online.de/sachse-stollen-stollen...
# 2  Bäckerei Sachse   - 1kg  https://kokku-online.de/sachse-stollen-veganer...
# 3  Bäckerei Sachse  - 250g  https://kokku-online.de/sachse-stollen-3-stoll...
# 4  Bäckerei Sachse   - 1kg  https://kokku-online.de/sachse-stollen-dinkels...
#
#      price    price_gr                                         nutritions  \
# 0   1.49 €  1.99€/100g  Brennwert1.632 kJ / 384 kcalFett< 0,1g- davon ...
# 1   2.99 €  2.99€/100g  Brennwert1912 kJ / 457 kcalFett26,7g- davon ge...
# 2  19.99 €   19.99€/kg  Brennwert1763 kJ / 421 kcalFett20,3g- davon ge...
# 3   4.99 €  2.00€/100g  Brennwert1763 kJ / 421 kcalFett20,3g- davon ge...
# 4  19.99 €   19.99€/kg  Brennwert1572 kJ / 375 kcalFett14,915,1g- davo...
#
#                                           photo_link
# 0  https://kokku-online.de//bilder/350x350/19266/...
# 1  https://kokku-online.de//bilder/350x350/12280/...
# 2  https://kokku-online.de//bilder/350x350/7806/s...
# 3  https://kokku-online.de//bilder/350x350/6140/s...
# 4  https://kokku-online.de//bilder/350x350/6167/s...

# %% [markdown]
# ### Cleaning overview
#
# - [x] removing duplicate index column
# - [x] removing weight from product name
# - [x] removing extra charcters from weight + changing column type
# - [x] removing extra characters from price + changing column type
# - [ ] splitting nutrition column: kcal, fat, sat_fat, carbs, sugar, fibre, protein, salt
#
# Maybe:
#
# - [ ] cleaning price_gr column?

# %% [markdown]
# **Dropping duplicate index column**

# %%
kokku= kokku.drop('Unnamed: 0', axis=1)
kokku.columns
# Out:
# Index(['product', 'brand', 'weight', 'links', 'price', 'price_gr',
#        'nutritions', 'photo_link'],
#       dtype='object')

# %% [markdown]
# **Cleaning product name**

# %%
kokku['product'].value_counts()
# Out:
# Kakao Nibs Natur - 100g                           2
# Schokotäfelchen 3er-Set - 120g                    2
# Kakaobohnen Peru geröstet - 100g                  2
# °Glücksstücke° - 70g                              1
# Veggie Vine Gums - 100g                           1
#                                                  ..
# Lateinamerika Edelbitter Schokolade 100% - 80g    1
# Nougat Lebkuchen Taler - 150g                     1
# Laugenstangen 2x80g - 160g                        1
# Erdbeer Rhabarber Fruchtkonfekt - 80g             1
# Veggie Hearts - 100g                              1
# Name: product, Length: 546, dtype: int64

# %%
def clean_name_kokku(x):
    return re.sub(r'[-]\s\d{2,3}\w+|[-]\s\d{1}\w+', '', x)

# %%
kokku["product_clean"] = kokku["product"].apply(clean_name_kokku)
kokku["product_clean"].sample(10)
# Out:
# 58                             Edel Bitter Chili
# 101                      Tafel °Mandel & Baobab°
# 451               So Free Hanfsamen °zuckerfrei°
# 536           Helle Schokolade MaplePekan & Salz
# 494                          Lutscher °Erdbeere°
# 468                        Riegel °Mandel Feige°
# 446    °White Chocolate Macadamia° Energieriegel
# 289                     Kinderriegel Starry Inca
# 447       °Chocolate Almond Fudge° Energieriegel
# 297                      Mini Mandel Spekulatius
# Name: product_clean, dtype: object

# %% [markdown]
# **Cleaning weight**

# %%
kokku['weight'] = kokku['weight'].str.replace('- ', '')

# %%
#removing kg

def clean_weight(col):
    
    clean_weight = []
    
    for w in col:
        if w.endswith('kg'):
            w = w.replace('kg', '')
            w = float(w)
            clean_weight.append(w)
            
        elif w.endswith('g'):
            w = w.replace('g', '')
            w = float(w)
            w = w/1000
            clean_weight.append(w)
        
        else:
            clean_weight.append(w)
    
    return clean_weight

# %%
kokku['clean_weight'] = clean_weight(kokku['weight'])
kokku['clean_weight']
# Out:
# 0      0.075
# 1        0.1
# 2        1.0
# 3       0.25
# 4        1.0
#        ...
# 544    0.017
# 545    0.017
# 546    0.065
# 547     0.07
# 548    0.045
# Name: clean_weight, Length: 549, dtype: object

# %% [markdown]
# **Cleaning price**

# %%
kokku['price'].value_counts()
# Out:
# 2.49 €           78
# 1.99 €           43
# 2.99 €           39
# 0.99 €           32
# 2.59 €           23
#                  ..
# 7.39 €            1
# 14.99 €           1
# 6.99 €            1
# 4.39 €            1
# bisher 4.19 €     1
# Name: price, Length: 77, dtype: int64

# %%
kokku['clean_price'] = kokku['price'].str.replace(' €', '').str.replace('bisher ', '').astype('float')
kokku['clean_price']
# Out:
# 0       1.49
# 1       2.99
# 2      19.99
# 3       4.99
# 4      19.99
#        ...
# 544     1.29
# 545     1.29
# 546     1.99
# 547     2.99
# 548     1.99
# Name: clean_price, Length: 549, dtype: float64

# %% [markdown]
# **Cleaning nutrients**

# %%
kokku['nutritions'].value_counts()
# Out:
# Brennwert2715 kJ / 655 kcalFett46g- davon gesättigte Fettsäuren28gKohlenhydrate31g- davon Zucker1gEiweiß9,2gSalz0,07g                6
# Brennwert2458 kJ / 591 kcalFett41g- davon gesättigte Fettsäuren24gKohlenhydrate51g- davon Zucker42,5gEiweiß2,8gSalz0,07g             4
# Brennwert2458 kJ / 591 kcalFett40,9g- davon gesättigte Fettsäuren24gKohlenhydrate51,1g- davon Zucker42,5gEiweiß2,8gSalz0,07g         4
# Brennwert1372 kJ / 323 kcalFett0,1g- davon gesättigte Fettsäuren0,1gKohlenhydrate78g- davon Zucker58gEiweiß<0,2gSalz0,75g            4
# Brennwert2425 kJ / 585 kcalFett44.9g- davon gesättigte Fettsäuren28.3gKohlenhydrate32.5g- davon Zucker27gEiweiß7gSalz< 0.02g         4
#                                                                                                                                     ..
# Brennwert2310 kJ / 551 kcalFett36g- davon gesättigte Fettsäuren21gKohlenhydrate56g- davon Zucker42gEiweiß2,5gSalz0,25g               1
# Brennwert2429 kJ / 584 kcalFett42g- davon gesättigte Fettsäuren25,7gKohlenhydrate46,9g- davon Zucker43gEiweiß2,5gSalz0,04g           1
# Brennwert2527 kJ / 611 kcalFett45g- davon gesättigte Fettsäuren28gKohlenhydrate24g- davon Zucker3,9gEiweiß6,5gSalz0,03g              1
# Brennwert2447 kJ / 585 kcalFett38,9g- davon gesättigte Fettsäuren11,4gKohlenhydrate50,5g- davon Zucker46,7gEiweiß5,9gSalz0,4g        1
# Brennwert2431 kJ / 589 kcalFett50,35g- davon gesättigte Fettsäuren32,06gKohlenhydrate14,2g- davon Zucker7,3gEiweiß12,18gSalz0,05g    1
# Name: nutritions, Length: 502, dtype: int64

# %%
def clean_nutrients(col):
    
    kcals = []
    fats = []
    sat_fats = []
    carbs = []
    sugars = []
    proteins = []
    salts = []
    
    for n in col:
        
        kcal = re.findall()
        kcals.append(kcal)
        
        fat = re.findall()
        fats.append(fat)
        
        sat_fat = re.findall()
        kcals.append(sat_fat)
        
        carb = re.findall()
        carbs.append(carb)
        
        sugar = re.findall()
        sugars.append(sugar)
        
        protein = re.findall()
        proteins.append(protein)
        
        salt = re.findall()
        salts.append(salt)
        
    return [kcals, fats, sat_fats, carbs, sugars, proteins, salts]

# %%
kokku[['kcal', 'rest']] = kokku['nutritions'].str.split('Fett', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-9a1ee092db33> in <module>
# ----> 1 kokku[['kcal', 'rest']] = kokku['nutritions'].str.split('Fett', expand=True)
#
# c:\users\katha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# c:\users\katha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3187             if isinstance(value, DataFrame):
#    3188                 if len(value.columns) != len(key):
# -> 3189                     raise ValueError("Columns must be same length as key")
#    3190                 for k1, k2 in zip(key, value.columns):
#    3191                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key
